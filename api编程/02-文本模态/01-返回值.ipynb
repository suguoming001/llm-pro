# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv(override=True)

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_BASE_URL"),
)

# %%
# user角色： 用户输入的内容  ==> 提交给模型
    
response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role":"user", "content": "请介绍一下你自己。"}  
    ]
)

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-DQv1bquNxwQPnCUB1OronpJfGyHBy', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='你好，我是一个由人工智能驱动的语言模型，可以用中文、英文等多种语言进行交流。我的主要功能是理解并生成自然语言内容，帮助你获取信息、解答问题、提供建议，以及陪你聊天或创作。\n\n我没有个人经历或情感，但可以根据训练时学到的知识和语言规律，模拟出自然且有逻辑的回应。我的知识范围覆盖科学、历史、文化、科技、生活等多个领域，不过需要注意，我的知识截至到 **2024年6月**，对于之后发生的事件可能并不了解。\n\n如果你愿意，可以告诉我你的需求，比如：\n- 查找或解释某个概念\n- 讨论有趣的话题\n- 帮助学习或写作\n- 提供创意或计划建议\n\n你想让我用更轻松的口吻还是更专业的风格和你聊天呢？', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1775308103, model='gpt-5-nano-2025-08-07', object='chat.completion', service_tier=None, system_fingerprint='fp_1133e9eff6', usage=CompletionUsage(completion_tokens=195, prompt_tokens=13, total_tokens=208, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=195, prompt_tokens=13, total_tokens=208, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
print(f"Prompt Tokens: {response.usage.prompt_tokens}")
print(f"Completion Tokens: {response.usage.completion_tokens}")
print(f"Total Tokens: {response.usage.total_tokens}")
# Out:
# Prompt Tokens: 13
# Completion Tokens: 195
# Total Tokens: 208

# %%
# print(response.choices[0].message.content)

response.choices[0].message.content
# Out:
# '你好，我是一个由人工智能驱动的语言模型，可以用中文、英文等多种语言进行交流。我的主要功能是理解并生成自然语言内容，帮助你获取信息、解答问题、提供建议，以及陪你聊天或创作。\n\n我没有个人经历或情感，但可以根据训练时学到的知识和语言规律，模拟出自然且有逻辑的回应。我的知识范围覆盖科学、历史、文化、科技、生活等多个领域，不过需要注意，我的知识截至到 **2024年6月**，对于之后发生的事件可能并不了解。\n\n如果你愿意，可以告诉我你的需求，比如：\n- 查找或解释某个概念\n- 讨论有趣的话题\n- 帮助学习或写作\n- 提供创意或计划建议\n\n你想让我用更轻松的口吻还是更专业的风格和你聊天呢？'

# %%
response.choices[0].message.role
# Out:
# 'assistant'
