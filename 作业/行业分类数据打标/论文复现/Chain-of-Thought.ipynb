# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv(override=True)

client = OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url=os.getenv("OPENROUTER_BASE_URL"),
)

# %%
prompt = """
输入从1到500的数字需要多少次击键？"""
response = client.chat.completions.create(
    model="openai/gpt-3.5-turbo",
    messages=[{"role": "user", "content": prompt}]
)
print(response.choices[0].message.content)
# Out:
# 要输入从1到500的数字，每个数字至少需要输入三位数，例如1需要输入001。因此，每次击键需要输入三位数，共需要500次击键。

# %%
prompt = """
梨会沉入水中吗？"""
response = client.chat.completions.create(
    model="opeanai/gpt-3.5-turbo",
    messages=[{"role": "user", "content": prompt}]
)
print(response.choices[0].message.content)
# Out:
# 是的，梨会沉入水中。因为梨的密度比水大，所以梨会下沉到水底。而如果梨的熟透度很高，就可能会漂浮在水面上。

# %%
prompt = """
音乐会原定于1943年6月1日举行，但推迟了一天到今天。10天前的日期（MM/DD/YYYY）是多少？"""
response = client.chat.completions.create(
    model="openai/gpt-3.5-turbo",
    messages=[{"role": "user", "content": prompt}]
)
print(response.choices[0].message.content)
# Out:
# 05/22/1943

# %%
prompt = """
 “Joao Moutinho 在 NFC 冠军赛中接住了屏幕传球”这句话合理吗？"""
response = client.chat.completions.create(
    model="openai/gpt-3.5-turbo",
    messages=[{"role": "user", "content": prompt}]
)
print(response.choices[0].message.content)
# Out:
# 不合理。Joao Moutinho是葡萄牙的足球运动员，而NFC冠军赛是美国橄榄球赛事。因此，这句话不合乎事实。

# %%
prompt = """
 “取出“Lady Gaga”中每个单词的最后一个字母并拼接。"""
response = client.chat.completions.create(
    model="openai/gpt-3.5-turbo",
    messages=[{"role": "user", "content": prompt}]
)
print(response.choices[0].message.content)
# Out:
# 结果是"ayaa"

# %%
few_shots = """
Q：“罗杰有五个网球，他又买了两盒网球，每盒有3个网球，请问他现在总共有多少个网球？” \
A：“罗杰一开始有5个球。2罐每罐3个球是6个球。5 + 6 = 11。答案是11。” \
Q：“食堂总共有23个苹果，如果他们用掉20个苹果，然后又买了6个苹果，请问现在食堂总共有多少个苹果？” \
A：“食堂最初有23个苹果。用了20个做午餐，所以还剩 23 - 20 = 3 个。又买了6个，所以现在有 3 + 6 = 9 个。答案是9” \
Q：“输入从1到500的数字需要多少次击键？” \
A：“1到9有9个一位数。10到99有90个两位数。100到500有401个三位数。计算过程为：9 + 90(2) + 401(3) = 1392。答案是1392” \
Q: "梨会沉入水中吗？" \
A: "梨的密度约为 0.6 g/cm³，小于水的密度。因此，梨会漂浮。所以答案是否定的" \
Let’s think step by step.
"""

# %%
prompt = """
音乐会原定于1943年6月1日举行，但推迟了一天到今天。10天前的日期（MM/DD/YYYY）是多少"""
response = client.chat.completions.create(
    model="openai/gpt-3.5-turbo",
    messages=[{"role": "system", "content": few_shots},
              {"role": "user", "content": prompt}]
)
print(response.choices[0].message.content)
# Out:
# 今天的日期是1943年6月2日。所以10天前的日期是1943年5月23日。格式为05/23/1943。

# %%
prompt = """
硬币正面向上。Maybelle 翻转了硬币。Shalonda 没有翻转。硬币现在还是正面向上吗？"""
response = client.chat.completions.create(
    model="openai/gpt-3.5-turbo",
        messages=[{"role": "system", "content": "Let’s think step by step."},
              {"role": "user", "content": prompt}]
)
print(response.choices[0].message.content)
# Out:
# 根据你的描述，硬币一开始是正面向上的，Maybelle 翻转了硬币，但Shalonda 没有翻转。如果硬币只被翻转了一次，并且Shalonda没有翻转硬币，那么硬币现在应该是正面向上的。
